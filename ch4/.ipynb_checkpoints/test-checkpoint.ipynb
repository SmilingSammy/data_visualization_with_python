# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

path = '/Users/hsy/Library/Fonts/NanumGothic.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
plt.rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 부호 깨짐 방지

# %%
data = pd.read_csv('../data/human_info.csv', encoding='cp949')
data.head()
# Out:
#   gender  age marriage religion  income
# 0     남자   40       이혼       있슴     135
# 1     남자   40       이혼       있슴     196
# 2     남자   40       이혼       있슴     193
# 3     남자   40       이혼       없슴     159
# 4     남자   40       이혼       없슴     195

# %% [markdown]
# # 1

# %%
sns.countplot(x='marriage', data=data, order=['결혼', '이혼', '미혼'])
plt.title('결혼 유무에 따른 빈도')
# Out:
# Text(0.5, 1.0, '결혼 유무에 따른 빈도')

# %% [markdown]
# # 2

# %%
sns.countplot(x='marriage', hue='religion', data=data, order=['결혼', '이혼', '미혼'])
plt.title('결혼 유무에 vs 종교 유무 빈도')
# Out:
# Text(0.5, 1.0, '결혼 유무에 vs 종교 유무 빈도')

# %% [markdown]
# # 3

# %%
sns.distplot(x=data['age'], kde=True)
plt.title('kde와 histogram')
# Out:
# Text(0.5, 1.0, 'kde와 histogram')

# %% [markdown]
# # 4

# %%
data.head(1)
# Out:
#   gender  age marriage religion  income
# 0     남자   40       이혼       있슴     135

# %%
pv = pd.pivot_table(data, index='gender', columns='marriage', values='age')

# %%
sns.heatmap(pv, annot=True)
plt.title('결혼 유무와 성별에 대한 히트맵')
# Out:
# Text(0.5, 1.0, '결혼 유무와 성별에 대한 히트맵')

# %% [markdown]
# # 5

# %%
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
plt.title('상관 관계 시각화')
# Out:
# Text(0.5, 1.0, '상관 관계 시각화')

# %% [markdown]
# # 6

# %%
sns.pairplot(data=data[['income', 'age', 'marriage']], hue='marriage')

# %% [markdown]
# # 7

# %%
sns.violinplot(data.age)
plt.title('나이에 대한 바이올린 그래프')
# Out:
# Text(0.5, 1.0, '나이에 대한 바이올린 그래프')

# %% [markdown]
# # 8

# %%
sns.lmplot(x='age', y='income', hue='marriage', height=8, data=data)
plt.title('나이의 소득에 대하여 결혼 여부 lmplot 그래프')
# Out:
# Text(0.5, 1.0, '나이의 소득에 대하여 결혼 여부 lmplot 그래프')

# %% [markdown]
# # 9

# %%
def newAge(x):
    if x < 40:
        return '청년'
    elif x >= 40 and x < 50:
        return '중년'
    else :
        return '노년'

data['ageg'] = data['age'].apply(newAge)

# %%
sns.relplot(x='age', y='income', row='ageg', col='marriage', hue='gender', data=data, palette='CMRmap_r')

# %% [markdown]
# # 10

# %%
sns.jointplot(x='age', y='income', data=data)

# %% [markdown]
# # 11

# %%
sns.barplot(x='income', y='gender', data=data, hue='religion', errwidth=0)
# Out:
# <AxesSubplot:xlabel='income', ylabel='gender'>
